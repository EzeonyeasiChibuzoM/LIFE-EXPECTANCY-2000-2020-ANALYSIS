# %%
# Importing Visualization Libraries and Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# Define path
path = r'C:\\Users\\nakarton\\Downloads\\NakartonDataFiles\\Life Expectancy 2000-2020'

# %%
path
# Out:
# 'C:\\\\Users\\\\nakarton\\\\Downloads\\\\NakartonDataFiles\\\\Life Expectancy 2000-2020'

# %%
# Import Dataset
df_life_clean = pd.read_csv(r'C:\Users\nakarton\Downloads\NakartonDataFiles\Life Expectancy 2000-2020\02 Data\Prepared Data\life_expectancy_clean.csv', index_col = False)

# %%
df_life_clean.head()
# Out:
#    Unnamed: 0  Country  Year Continent  Least Developed  life_expect  \
# 0           0  Albania  2000    Europe            False       73.955
# 1           1  Albania  2001    Europe            False       74.288
# 2           2  Albania  2002    Europe            False       74.579
# 3           3  Albania  2003    Europe            False       74.828
# 4           4  Albania  2004    Europe            False       75.039
#
#    Population  CO2_emiss  health_spend  electric_consumption  forest_area  \
# 0     3089027   1.026213      7.233370           1414.703784    28.076642
# 1     3060173   1.055496      7.139524           1449.647413    28.123248
# 2     3051010   1.232379      6.909341           1351.230796    28.169854
# 3     3039616   1.338985      7.063490           1578.165919    28.216460
# 4     3026939   1.404059      6.773372           1469.264539    28.263066
#
#    gdp_per_capita  internet_usage  military_spend  open_defecation  \
# ...

# %%
# Data Cleaning

# %%
df_life_clean.shape
# Out:
# (1904, 18)

# %%
df_life_clean.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Year', 'Continent', 'Least Developed',
#        'life_expect', 'Population', 'CO2_emiss', 'health_spend',
#        'electric_consumption', 'forest_area', 'gdp_per_capita',
#        'internet_usage', 'military_spend', 'open_defecation',
#        'drinking_water_services', 'adult_obesity', 'beer_consumption'],
#       dtype='object')

# %%
df_life_clean.dtypes

# %%
# Drop Columns
df_life_clean.drop(columns = ['Unnamed: 0', 'Least Developed', 'electric_consumption', 'forest_area', 'gdp_per_capita', 'military_spend'])
# Out:
#        Country  Year Continent  life_expect  Population  CO2_emiss  \
# 0      Albania  2000    Europe       73.955     3089027   1.026213
# 1      Albania  2001    Europe       74.288     3060173   1.055496
# 2      Albania  2002    Europe       74.579     3051010   1.232379
# 3      Albania  2003    Europe       74.828     3039616   1.338985
# 4      Albania  2004    Europe       75.039     3026939   1.404059
# ...        ...   ...       ...          ...         ...        ...
# 1899  Zimbabwe  2011    Africa       52.896    12894323   0.884886
# 1900  Zimbabwe  2012    Africa       55.032    13115149   0.915735
# 1901  Zimbabwe  2013    Africa       56.897    13350378   0.919824
# 1902  Zimbabwe  2014    Africa       58.410    13586710   0.889104
# 1903  Zimbabwe  2015    Africa       59.534    13814642   0.899770
#
#       health_spend  internet_usage  open_defecation  drinking_water_services  \
# 0         7.233370        0.114097         0.888853                86.754471
# ...

# %%
df_life_clean = df_life_clean.drop(columns = ['Unnamed: 0', 'Least Developed', 'electric_consumption', 'forest_area', 'gdp_per_capita', 'military_spend'])

# %%
df_life_clean
# Out:
#        Country  Year Continent  life_expect  Population  CO2_emiss  \
# 0      Albania  2000    Europe       73.955     3089027   1.026213
# 1      Albania  2001    Europe       74.288     3060173   1.055496
# 2      Albania  2002    Europe       74.579     3051010   1.232379
# 3      Albania  2003    Europe       74.828     3039616   1.338985
# 4      Albania  2004    Europe       75.039     3026939   1.404059
# ...        ...   ...       ...          ...         ...        ...
# 1899  Zimbabwe  2011    Africa       52.896    12894323   0.884886
# 1900  Zimbabwe  2012    Africa       55.032    13115149   0.915735
# 1901  Zimbabwe  2013    Africa       56.897    13350378   0.919824
# 1902  Zimbabwe  2014    Africa       58.410    13586710   0.889104
# 1903  Zimbabwe  2015    Africa       59.534    13814642   0.899770
#
#       health_spend  internet_usage  open_defecation  drinking_water_services  \
# 0         7.233370        0.114097         0.888853                86.754471
# ...

# %%
# Exploring Relationships

# %%
# Selecting only numeric columns
numeric_df_life_clean = df_life_clean.select_dtypes(include=np.number)

# %%
# Computing the correlation matrix
corr_matrix = numeric_df_life_clean.corr()

# %%
# Create a correlation heatmap using matplotlib
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# Save the plot
plt.savefig('correlation_heatmap.png')

# %%
# Create the heatmap using Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.xlabel('Variables')
plt.ylabel('Variables')
plt.show()

# %%
# Question - What is the population of adults with obesity?

# %%
# Create a scatterplot for the columns 'Population' & 'adult_obesity' in seaborn
sns.lmplot(x = 'Population', y = 'life_expect', data = df_life_clean)
# Out:
# C:\Users\nakarton\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Question - What is the population of people using basic drinking water services?

# %%
# Create a scatterplot for the columns 'Population' & 'drinking_water_services' in seaborn
sns.lmplot(x = 'Population', y = 'drinking_water_services', data = df_life_clean)
# Out:
# C:\Users\nakarton\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Question - Which countries have the highest and lowest internet usage?

# %%
# Create a scatterplot for the columns 'internet_usage' & 'life_expect' in seaborn
sns.lmplot(x = 'internet_usage', y = 'life_expect', data = df_life_clean)
# Out:
# C:\Users\nakarton\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Question - How does people using basic drinking water services affect life expectancy?

# %%
# Create a scatterplot for the columns 'drinking_water_services' & 'life_expect' in seaborn
sns.lmplot(x = 'drinking_water_services', y = 'life_expect', data = df_life_clean)
# Out:
# C:\Users\nakarton\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Keep only the variables you want to use in the pair plot
sub = df_life_clean[['life_expect', 'adult_obesity', 'drinking_water_services', 'Population', 'Year', 'internet_usage', 'CO2_emiss', 'open_defecation', 'health_spend', 'beer_consumption']]

# %%
# Create a pair plot
g = sns.pairplot(sub)
# Out:
# C:\Users\nakarton\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nakarton\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nakarton\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Categorical Plots
sns.histplot(df_life_clean['Population'], bins = 50, kde = True)
# Out:
# C:\Users\nakarton\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Population', ylabel='Count'>

# %%
df_life_clean.loc[df_life_clean['Population'] < 50, 'Population category'] = 'Low Population'

# %%
df_life_clean.loc[(df_life_clean['Population'] >= 50) & (df_life_clean['Population'] < 100), 'Population category'] = 'Middle Population'

# %%
df_life_clean.loc[df_life_clean['Population'] >= 100, 'Population category'] = 'High Population'

# %%
df_life_clean['Population category'].value_counts(dropna = False)
# Out:
# Population category
# High Population    1904
# Name: count, dtype: int64

# %%
df_life_clean.columns
# Out:
# Index(['Country', 'Year', 'Continent', 'life_expect', 'Population',
#        'CO2_emiss', 'health_spend', 'internet_usage', 'open_defecation',
#        'drinking_water_services', 'adult_obesity', 'beer_consumption',
#        'Population category'],
#       dtype='object')

# %%
# Set the Seaborn style
sns.set(style="ticks")

# %%
# Create the categorical plot
g = sns.catplot(x='Population', y='adult_obesity', hue='Population category', data=df_life_clean)
# Out:
# C:\Users\nakarton\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nakarton\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nakarton\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Save the plot
plt.savefig('g.png')

# %%
visualization1 = sns.histplot(df_life_clean['Population'], bins = 50, kde = True)
# Out:
# C:\Users\nakarton\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Export histplot
visualization1.figure.savefig(os.path.join(path, '04 Analysis','Visualizations', 'histplot.png'))

# %%
# Export your df_life dataframe as “life_expectancy_clean.pkl”
df_life_clean.to_csv(os.path.join(path, '02 Data','Prepared Data', 'life_expectancy_clean.csv'))
